# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter("ignore")

# %% [markdown]
# # Data import using pandas

# %%
data = pd.read_csv(r'C:\Users\sai chaitanya\Downloads\8. Netflix Dataset.csv')

# %%
data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
data.shape
# Out:
# (7789, 11)

# %%
data.size
# Out:
# 85679

# %%
data.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %% [markdown]
# # Null values form every column using heatmap

# %%
sns.heatmap(data.isnull())
plt.show()

# %%
# Elemination of  duplicates
data[data.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
data.drop_duplicates(inplace = True)

# %% [markdown]
# # finding the director and of show selected

# %%
sherlock = data[data['Title'].isin(['Sherlock Holmes'])]

# %%
sherlock[['Director','Category','Release_Date']]
# Out:
#          Director Category     Release_Date
# 5564  Guy Ritchie    Movie  January 1, 2021

# %% [markdown]
# # in which year most of the shows are released to netfilx

# %%
# we need to convert the date column to datetime series
data.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
# use date time function from pandas
# by creating new column 
data['date_new'] = pd.to_datetime(data['Release_Date'])

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
# created the datetime object column for most shows per yearr
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7787 entries, 0 to 7788
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7787 non-null   object
#  1   Category      7787 non-null   object
#  2   Title         7787 non-null   object
#  3   Director      5399 non-null   object
#  4   Cast          7069 non-null   object
#  5   Country       7280 non-null   object
#  6   Release_Date  7777 non-null   object
#  7   Rating        7780 non-null   object
#  8   Duration      7787 non-null   object
#  9   Type          7787 non-null   object
#  10  Description   7787 non-null   object
#  11  date_new      7777 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), object(11)
# memory usage: 790.9+ KB

# %%
data['date_new'].dt.year.value_counts().reset_index()



# by this, we can  most tv shows are released in 2019
# Out:
#      index  date_new
# 0   2019.0      2153
# 1   2020.0      2009
# 2   2018.0      1685
# 3   2017.0      1225
# 4   2016.0       443
# 5   2021.0       117
# 6   2015.0        88
# 7   2014.0        25
# 8   2011.0        13
# 9   2013.0        11
# 10  2012.0         3
# 11  2009.0         2
# 12  2008.0         2
# 13  2010.0         1

# %% [markdown]
# # visualizing tv show releases by year with bar graph

# %%
data['date_new'].dt.year.value_counts().plot(kind='bar',color='red')
plt.show()

# %% [markdown]
# # all TV shows and movies on the dataset

# %%
# by grouping the most occurences will be grouped then we can count them
data.groupby('Category').Category.count()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
#visualization part
sns.countplot(data['Category'])
plt.show()

# %% [markdown]
# # movies added in year 2000

# %%
#create a column of years
data['year'] = data['date_new'].dt.year

# %%
data.head(5)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
#check how many movies released
data[(data['year'] == 2000.0)&(data['Category'] == 'Movie')]
# no movies released in 2000
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, date_new, year]
# Index: []

# %%
# movies in 2020
movies_in_2020 = data[(data['year'] == 2020.0) & (data['Category'] == 'Movie')]
movies_in_2020
# Out:
#      Show_Id Category                                    Title  \
# 4         s5    Movie                                       21
# 6         s7    Movie                                      122
# 14       s15    Movie                                     3022
# 27       s28    Movie                                   #Alive
# 28       s29    Movie            #AnneFrank - Parallel Stories
# ...      ...      ...                                      ...
# 7762   s7761    Movie                                Zaki Chan
# 7783   s7782    Movie                                     Zoom
# 7784   s7783    Movie                                     Zozo
# 7786   s7785    Movie                        Zulu Man in Japan
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                          Director  \
# 4                  Robert Luketic
# 6                 Yasir Al Yasiri
# 14                     John Suits
# 27                         Cho Il
# ...

# %%
# find count of  movies in 2020 is 
len(movies_in_2020)
# Out:
# 1312

# %% [markdown]
# # tv shows released in india only.

# %%
data[(data['Category'] == 'TV Show')&(data['Country'] == 'India')]['Title']
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %% [markdown]
# # who are the top directors gave number of tv shows and movies

# %%
data['Director'].value_counts().head(10)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Martin Scorsese           12
# Youssef Chahine           12
# Steven Spielberg          10
# David Dhawan               9
# Lance Bangs                8
# Name: Director, dtype: int64

# %% [markdown]
# # what are movies that are comedies or released on UK

# %%
data[(data['Category'] == 'Movie') & (data['Type'] == 'Comedies')]#|data['Country']=='United Kingdom')]
# Out:
#      Show_Id Category                        Title                Director  \
# 33       s34    Movie                 #realityhigh        Fernando Lebrija
# 72       s73    Movie                     17 Again             Burr Steers
# 84       s85    Movie                    21 & Over  Jon Lucas, Scott Moore
# 148     s149    Movie         A Bad Moms Christmas  Jon Lucas, Scott Moore
# 174     s175    Movie  A Futile and Stupid Gesture              David Wain
# ...      ...      ...                          ...                     ...
# 7341   s7340    Movie         Undercover Brother 2            Leslie Small
# 7590   s7589    Movie            Where's the Money         Scott Zabielski
# 7623   s7622    Movie                    Wild Oats            Andy Tennant
# 7634   s7633    Movie                 Wine Country             Amy Poehler
# 7664   s7663    Movie                      Work It           Laura Terruso
#
#                                                    Cast  \
# ...

# %%
data[(data['Category'] == 'Movie') & (data['Type'] == 'Comedies')|(data['Country']=='United Kingdom')]
# Out:
#      Show_Id Category                   Title          Director  \
# 19       s20    Movie                     '89               NaN
# 33       s34    Movie            #realityhigh  Fernando Lebrija
# 58       s59  TV Show             100% Hotter               NaN
# 72       s73    Movie                17 Again       Burr Steers
# 82       s83    Movie     2036 Origin Unknown     Hasraf Dulull
# ...      ...      ...                     ...               ...
# 7670   s7669  TV Show  World War II in Colour               NaN
# 7671   s7670  TV Show  World's Busiest Cities               NaN
# 7688   s7687    Movie  XV: Beyond the Tryline  Pierre Deschamps
# 7725   s7724    Movie            You Can Tutu       James Brown
# 7740   s7739  TV Show         Young Wallander               NaN
#
#                                                    Cast         Country  \
# 19                   Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# ...

# %% [markdown]
# # how many movies Tom Cruise was a cast

# %%
data[data['Cast']=='Tom Cruise'] # because of more strings
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, date_new, year]
# Index: []

# %%
#by using str.contains

data[data['Cast'].str.contains('Tom Cruise')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-282deea525c0> in <module>
#       1 #by using str.contains
#       2
# ----> 3 data[data['Cast'].str.contains('Tom Cruise')]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2890
#    2891         # Do we have a (boolean) 1d indexer?
# -> 2892         if com.is_bool_indexer(key):
#    2893             return self._getitem_bool_array(key)
#    2894
#
# ~\anaconda3\lib\site-packages\pandas\core\common.py in is_bool_indexer(key)
#     132                 na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     133                 if isna(key).any():
# --> 134                     raise ValueError(na_msg)
#     135                 return False
#     136             return True
#
# ValueError: Cannot mask with non-boolean array containing NA / NaN values

# %%
#removing null values to get the ouput
df = data.dropna()

# %%
df[df['Cast'].str.contains('Tom Cruise')]

# %% [markdown]
# # ratings by netflix

# %%
df['Rating'].nunique()

# %%
df['Rating'].unique()

# %%
#specific rating in canada
df[(df['Category']=='Movie')&(df['Rating']=='TV-14')]

# %%
df[(df['Category']=='Movie')&(df['Rating']=='TV-14')&(df['Country'] == 'Canada')]

# %% [markdown]
# # R rating tv shows in year 2018

# %%
data[(data['Category'] == 'TV Show')&(data['Rating']=='R')]

# %%
data[(data['Category'] == 'TV Show') & (data['Rating']=='R') & (data['year'] > 2018)]

# %% [markdown]
# #  duration of movies and TV shows

# %%
data.Duration.unique()
# Out:
# array(['4 Seasons', '93 min', '78 min', '80 min', '123 min', '1 Season',
#        '95 min', '119 min', '118 min', '143 min', '103 min', '89 min',
#        '91 min', '149 min', '144 min', '124 min', '87 min', '110 min',
#        '128 min', '117 min', '100 min', '2 Seasons', '84 min', '99 min',
#        '90 min', '102 min', '104 min', '105 min', '56 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '109 min', '44 min',
#        '75 min', '101 min', '3 Seasons', '37 min', '113 min', '114 min',
#        '130 min', '94 min', '140 min', '135 min', '82 min', '70 min',
#        '121 min', '92 min', '164 min', '53 min', '83 min', '116 min',
#        '86 min', '120 min', '96 min', '126 min', '129 min', '77 min',
#        '137 min', '148 min', '28 min', '122 min', '176 min', '85 min',
#        '22 min', '68 min', '111 min', '29 min', '142 min', '168 min',
#        '21 min', '59 min', '20 min', '98 min', '108 min', '76 min',
# ...

# %%
data.Duration.dtypes
# Out:
# dtype('O')

# %%
#seperated the numric values and strings using split to two columns
data[['minutes','unit']] = data['Duration'].str.split(' ',expand = True)

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data.minutes.max() # this is the wrong value because of string format
# Out:
# '99'

# %%
# conversion of string from of numeric to integer'
data['minutes'] = data.minutes.astype(int)

# %%
# by converting we get
data.minutes.max()
# Out:
# 312

# %%
# min duration is
data.minutes.min() # this is  the season
# Out:
# 1

# %% [markdown]
# # which country has most tv shows

# %%
tv_show = data[data['Category'] == 'TV Show']

# %%
tv_show
# Out:
#      Show_Id Category                  Title              Director  \
# 0         s1  TV Show                     3%                   NaN
# 5         s6  TV Show                     46           Serdar Akar
# 11       s12  TV Show                   1983                   NaN
# 12       s13  TV Show                   1994  Diego Enrique Osorno
# 16       s17  TV Show                 Feb-09                   NaN
# ...      ...      ...                    ...                   ...
# 7769   s7768  TV Show     Zindagi Gulzar Hai                   NaN
# 7777   s7776  TV Show             Zoids Wild                   NaN
# 7779   s7778  TV Show            Zombie Dumb                   NaN
# 7781   s7780  TV Show              Zona Rosa                   NaN
# 7787   s7786  TV Show  Zumbo's Just Desserts                   NaN
#
#                                                    Cast  \
# 0     João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
tv_show.Country.value_counts().head(10)
# Out:
# United States     705
# United Kingdom    204
# Japan             157
# South Korea       147
# India              71
# Taiwan             68
# Canada             59
# Australia          46
# France             46
# Spain              45
# Name: Country, dtype: int64

# %% [markdown]
# # sorting data by year

# %%
df.sort_values('year')
# Out:
#      Show_Id Category                              Title  \
# 7115   s7114    Movie               To and From New York
# 5766   s5766    Movie                           Splatter
# 3248   s3249    Movie            Just Another Love Story
# 3840   s3841    Movie        Mad Ron's Prevues from Hell
# 3221   s3222    Movie             Joseph: King of Dreams
# ...      ...      ...                                ...
# 1426   s1427    Movie  Cloudy with a Chance of Meatballs
# 1739   s1740    Movie        Dhobi Ghat (Mumbai Diaries)
# 7553   s7552    Movie          What Happened to Mr. Cha?
# 2479   s2480    Movie                          Good Hair
# 3237   s3238    Movie                      Julie & Julia
#
#                            Director  \
# 7115           Sorin Dan Mihalcescu
# 5766                      Joe Dante
# 3248                   Ole Bornedal
# 3840                     Jim Monaco
# 3221  Rob LaDuca, Robert C. Ramirez
# ...                             ...
# ...

# %% [markdown]
# # how many kids shows on netflix

# %%
data[(data['Category']=='TV Show')&(data['Type'].str.contains('Kids'))]
# Out:
#      Show_Id Category                           Title     Director  \
# 108     s109  TV Show        3Below: Tales of Arcadia          NaN
# 111     s112  TV Show                         44 Cats          NaN
# 225     s226  TV Show  A Series of Unfortunate Events          NaN
# 276     s277  TV Show                    Abby Hatcher  Kyran Kelly
# 364     s365  TV Show                    Akbar Birbal          NaN
# ...      ...      ...                             ...          ...
# 7758   s7757  TV Show                              Z4          NaN
# 7761   s7760  TV Show                       Zak Storm          NaN
# 7768   s7767  TV Show                    Zig & Sharko          NaN
# 7777   s7776  TV Show                      Zoids Wild          NaN
# 7779   s7778  TV Show                     Zombie Dumb          NaN
#
#                                                    Cast  \
# 108   Tatiana Maslany, Diego Luna, Nick Offerman, Ni...
# ...
